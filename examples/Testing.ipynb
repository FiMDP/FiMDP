# %%
import sys; sys.path.insert(0, '..')
from cmdp.consMDP import ConsMDP
from cmdp.dot import consMDP2dot
from IPython.display import display, update_display

# THIS NEEDS DOT EXTENSION TO BE INSTALLED!
def display_graphviz(dot, mimetype="text/vnd.graphviz", **kwargs):
    """ Send some DOT to the frontend
    
    Get a handle to update later by calling `display_graphviz` with `display_id=True` 
    """
    #dot = open(file, 'r').read()
    return display({mimetype: dot}, raw=True, **kwargs)

def update_graphviz(dot, handle, mimetype="text/vnd.graphviz", **kwargs):
    """ Update an already-displayed DOT
    """
    update_display({mimetype: dot}, display_id=handle.display_id, raw=True, **kwargs)

# %%
m = ConsMDP()
m.new_state()
m.new_state()
d = {0: .5, 1: .5}

# %%
for l in "a":
    m.add_action(0, d, l)
    m.add_action(1, d, l)

# %%
m

# %%
display_graphviz(m._repr_dot_())

# %%
for a in m.actions_for_state(0):
    print(f"{a.src}->{a.distr}: {a.label}")
# Out:
# 0->{0: 0.5, 1: 0.5}: a

# %%
from reachability_examples import ultimate
m, T = ultimate()

# %%
m.get_Buchi(T)
# Out:
# [6, inf, inf, 3, 0, 1, 10, inf, 4, inf, inf]

# %%
print(m.get_dot())
# Out:
# digraph "" {
#   rankdir=LR
#
#   0 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">0</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">6</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">6</font></td></tr></table>>]
#     0 -> "0_a"[arrowhead=onormal,label="a: 1", color=black, fontcolor=black]
#     "0_a"[label=<>,shape=point]
#       "0_a" -> 1[label=0.5, color=gray52, fontcolor=gray52]      "0_a" -> 2[label=0.5, color=gray52, fontcolor=gray52]    0 -> "0_t"[arrowhead=onormal,label="t: 3", color=black, fontcolor=black]
#     "0_t"[label=<>,shape=point]
#       "0_t" -> 3[label=0.5, color=gray52, fontcolor=gray52]      "0_t" -> 4[label=0.5, color=gray52, fontcolor=gray52]
#   1 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">1</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">∞</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">∞</font></td></tr></table>>]
#     1 -> "1_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "1_"[label=<>,shape=point]
#       "1_" -> 2[label=1, color=gray52, fontcolor=gray52]
#   2 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">2</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">∞</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">∞</font></td></tr></table>>, peripheries=2]
#     2 -> "2_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "2_"[label=<>,shape=point]
#       "2_" -> 1[label=1, color=gray52, fontcolor=gray52]
#   3 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">3</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">3</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">3</font></td></tr></table>>]
#     3 -> "3_p"[arrowhead=onormal,label="p: 1", color=black, fontcolor=black]
#     "3_p"[label=<>,shape=point]
#       "3_p" -> 2[label=0.5, color=gray52, fontcolor=gray52]      "3_p" -> 7[label=0.5, color=gray52, fontcolor=gray52]    3 -> "3_r"[arrowhead=onormal,label="r: 2", color=black, fontcolor=black]
#     "3_r"[label=<>,shape=point]
#       "3_r" -> 5[label=1, color=gray52, fontcolor=gray52]    3 -> "3_a"[arrowhead=onormal,label="a: 3", color=black, fontcolor=black]
#     "3_a"[label=<>,shape=point]
#       "3_a" -> 6[label=1, color=gray52, fontcolor=gray52]
#   4 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">4</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">0</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">0</font></td></tr></table>>, peripheries=2]
#     4 -> "4_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "4_"[label=<>,shape=point]
#       "4_" -> 5[label=1, color=gray52, fontcolor=gray52]
#   5 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">5</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">1</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">1</font></td></tr></table>>]
#     5 -> "5_r"[arrowhead=onormal,label="r: 1", color=black, fontcolor=black]
#     "5_r"[label=<>,shape=point]
#       "5_r" -> 4[label=1, color=gray52, fontcolor=gray52]    5 -> "5_t"[arrowhead=onormal,label="t: 1", color=black, fontcolor=black]
#     "5_t"[label=<>,shape=point]
#       "5_t" -> 3[label=1, color=gray52, fontcolor=gray52]
#   6 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">6</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">10</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">10</font></td></tr></table>>]
#     6 -> "6_a"[arrowhead=onormal,label="a: 3", color=black, fontcolor=black]
#     "6_a"[label=<>,shape=point]
#       "6_a" -> 7[label=0.5, color=gray52, fontcolor=gray52]      "6_a" -> 10[label=0.5, color=gray52, fontcolor=gray52]    6 -> "6_B"[arrowhead=onormal,label="B: 6", color=black, fontcolor=black]
#     "6_B"[label=<>,shape=point]
#       "6_B" -> 3[label=0.5, color=gray52, fontcolor=gray52]      "6_B" -> 8[label=0.5, color=gray52, fontcolor=gray52]
#   7 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">7</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">∞</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">∞</font></td></tr></table>>, style="filled", fillcolor="#0000ff20"]
#     7 -> "7_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "7_"[label=<>,shape=point]
#       "7_" -> 9[label=1, color=gray52, fontcolor=gray52]
#   8 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">8</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">4</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">4</font></td></tr></table>>, style="filled", fillcolor="#0000ff20"]
#     8 -> "8_r"[arrowhead=onormal,label="r: 3", color=black, fontcolor=black]
#     "8_r"[label=<>,shape=point]
#       "8_r" -> 5[label=1, color=gray52, fontcolor=gray52]
#   9 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">9</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">∞</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">∞</font></td></tr></table>>, peripheries=2]
#     9 -> "9_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "9_"[label=<>,shape=point]
#       "9_" -> 9[label=1, color=gray52, fontcolor=gray52]
#   10 [label=<<table border="0" cellborder="0" cellspacing="0" cellpadding="1" align="center" valign="middle" style="rounded" bgcolor="#ffffff50"><tr><td rowspan="3">10</td></tr><tr><td></td></tr><tr><td align="center" valign="middle"><font color="forestgreen" point-size="10">∞</font></td><td align="center" valign="middle"><font color="darkgreen" point-size="10">∞</font></td></tr></table>>, style="filled", fillcolor="#0000ff20"]
#     10 -> "10_"[arrowhead=onormal,label=": 1", color=black, fontcolor=black]
#     "10_"[label=<>,shape=point]
#       "10_" -> 9[label=1, color=gray52, fontcolor=gray52]}

# %%
m
